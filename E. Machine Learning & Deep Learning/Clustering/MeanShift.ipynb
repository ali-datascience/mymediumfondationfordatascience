# %%
import numpy as np
from sklearn.cluster import MeanShift
from sklearn.datasets import make_blobs

# Generate sample data
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.6, random_state=0)

# Fit Mean Shift clustering model
ms = MeanShift()
ms.fit(X)

# Get cluster centers and labels
cluster_centers = ms.cluster_centers_
cluster_labels = ms.labels_

# Get number of clusters
n_clusters = len(cluster_centers)


print("Number of estimated clusters:", n_clusters)

# Predict cluster labels for new data points
new_data = np.array([[0, 0], [2, 2]])
predicted_labels = ms.predict(new_data)

print("Predicted cluster labels for new data points:", predicted_labels)
# Out:
# Number of estimated clusters: 2
# Predicted cluster labels for new data points: [0 0]
