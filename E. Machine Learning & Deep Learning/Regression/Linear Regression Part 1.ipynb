# %% [markdown]
# #Import *Library*

# %%
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #Create data synthesis

# %%
np.random.seed(10)
x= np.linspace(0,20,100) # Variabel independen
y = 3*x**2+2*x+np.random.normal(0,20,100) # Variabel Dependent

# %% [markdown]
# #Split the data

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# #Define the model

# %%
model = LinearRegression()
xtrain = x_train.reshape(-1,1)
model.fit(xtrain,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #Predict the data

# %%
xtest = x_test.reshape(-1,1)
ypred = model.predict(xtest)

# %% [markdown]
# #The plot look like

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=xtest.flatten(),y=y_test,mode='markers',name='Actual Data'))
fig.add_trace(go.Scatter(x=xtest.flatten(),y = ypred,mode='lines'))
fig.update_layout(title='Linear Regression')
xaxist_title='Independent variable x'
yaxist_title='Dependent variable y'
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
